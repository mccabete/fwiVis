# %%
#import fwiVis.fwiVis as fv
import s3fs
s3 = s3fs.S3FileSystem(anon=False)
from math import cos, asin, sqrt
import re

import numpy as np
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
import os
import rioxarray as rio
import xarray as xr
import rasterio
import glob
from shapely.errors import ShapelyDeprecationWarning
from shapely.geometry import Point
import warnings
import folium
import datetime
import time
from folium import plugins
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
import contextily as cx
from shapely.geometry import box
import sys
from datetime import datetime, timedelta
from itertools import chain

from datetime import date


sys.path.insert(0, '/projects/old_shared/fire_weather_vis/base-fwi-vis/')
import fwiVis.fwiVis as fv

# %%
pattern = '../**/*.ipynb' # extentions to look in
query = 'geojson' ## Text to search for

for filepath in glob.iglob(pattern, recursive=True):
    with open(filepath) as file:
        s = file.read()
        if (s.find(query) > -1):
            print(filepath)
# Out:
# ../test-of-rasterized-feds-ids.ipynb
# ../Quebec_fwi_viz/Canada_large_fires.ipynb
# ../fire_weather_vis/try_EOF.ipynb
# ../fire_weather_vis/Bolivia/Explore_bolivia.ipynb
# ../fire_weather_vis/station_utils_scripts/Quebec_station_vs_spread.ipynb
# ../fire_weather_vis/base-fwi-vis/Hermits_peak_for_zoey.ipynb
# ../fire_weather_vis/base-fwi-vis/precip_extinquish.ipynb
# ../fire_weather_vis/base-fwi-vis/rasterrize_year-2019.ipynb
# ../fire_weather_vis/base-fwi-vis/Compare_tina.ipynb
# ../fire_weather_vis/base-fwi-vis/Italy_greese_viz.ipynb
# ../fire_weather_vis/base-fwi-vis/Caldor_diurnal.ipynb
# ../fire_weather_vis/base-fwi-vis/rasterrize_year.ipynb
# ../fire_weather_vis/base-fwi-vis/CA_algo_demo_gif.ipynb
# ../fire_weather_vis/base-fwi-vis/fwiVis/Untitled4.ipynb
# ../fire_weather_vis/base-fwi-vis/Visualizations/Quick_park_viz.ipynb
# ../eis-fire-ans-demo/active-fires.ipynb
# ../eis-fire-ans-demo/geos-comparison.ipynb
# ../eis-fire-ans-demo/geos-comparison_leo.ipynb
# ../eis-fire-ans-demo/geos-comparison_mfc.ipynb
# ../Borneo/make_peat_landcover.ipynb
# ../eis-fire-visualization/EIS-Fire-Visualization/notebooks/SimpleVizDemo.ipynb
# ../eis-fire-visualization/EIS-Fire-Visualization/notebooks/EIS_Fire_Visualizations_UserDefinedShape-v1.0.0.ipynb
# ../eis-fire-visualization/EIS-Fire-Visualization/notebooks/EIS_Fire_Visualizations_1_v1.2.0.ipynb
# ../eis-fire-visualization/EIS-Fire-Visualization/notebooks/EIS_Fire_Visualizations_LatLon_v1.0.0.ipynb
