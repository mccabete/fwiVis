# %%
import s3fs
s3 = s3fs.S3FileSystem(anon=False)
from math import cos, asin, sqrt
import re

import numpy as np
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
import os
import xarray as xr
import rasterio
import glob
from shapely.errors import ShapelyDeprecationWarning
from shapely.geometry import Point
import warnings
import folium
import datetime
import time
from folium import plugins
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
from shapely.geometry import box
import sys
from datetime import datetime, timedelta

sys.path.insert(0, '/projects/fireatlas_nrt/fireatlas/')
#import Firelog, FireObj, FireIO, FireClustering, FireVector, FireConsts

#import fwiVis.fwiVis as fv

# %%
path = "/projects/shared-buckets/gsfc_landslides/FEDSoutput-s3-conus/QuebecGlobalNRT_3571/2023/Serialization/" + "20230801PM" + ".pkl"



## Load up pickle file?





import pickle





# open a file, where you stored the pickled data
file = open(path, 'rb')

# dump information to that file
data = pickle.load(file)

# close the file
file.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 21>()
#      18 file = open(path, 'rb')
#      20 # dump information to that file
# ---> 21 data = pickle.load(file)
#      23 # close the file
#      24 file.close()
#
# File ~/fireatlas_nrt/fireatlas/FireObj.py:15, in <module>
#      12 from datetime import date, timedelta
#      13 from shapely.geometry import MultiLineString, MultiPoint
# ---> 15 from fireatlas.utils import timed
#      16 from fireatlas.FireTime import t2dt, dt2t, t_nb, t_dif
#      17 from fireatlas.postprocess import read_allfires_gdf, read_allpixels
#
# File ~/fireatlas_nrt/fireatlas/__init__.py:11, in <module>
#       4     __version__ = "unknown"
#       6 from fireatlas import (
#       7     FireTypes,
#       8     FireTime,
#       9 )
# ---> 11 from fireatlas.FireConsts import Settings
#      13 # instantiate pydantic settings
#      14 settings = Settings()
#
# File ~/fireatlas_nrt/fireatlas/FireConsts.py:10, in <module>
#       7 import os
#       9 import fsspec
# ---> 10 from pydantic_settings import BaseSettings
#      11 from pydantic import Field, validator
#      13 from fireatlas.FireTypes import Location
#
# ModuleNotFoundError: No module named 'pydantic_settings'

# %%
# Out:
#   Input In [133]
#     0:len(data.fires[1462].pixels)
#     ^
# SyntaxError: illegal target for annotation

# %%
#data.fires[1462].pixels
times = []
for i in range(0, len(data.fires[1462].pixels)):
    #print(i)
    times.append(data.fires[1462].pixels[i].datetime)

# %%
times = pd.DataFrame(times, columns = ['t'])

times = times.sort_values(by = ['t'])
times["count"] = 1
times_grp = times.groupby("t").count()
times_grp["fireID"] = '1462'

# %%
times_grp
# Out:
#                      count fireID
# t
# 2023-07-07 06:29:00     13   1462
# 2023-07-07 07:20:00     22   1462
# 2023-07-07 08:09:00      2   1462
# 2023-07-07 16:20:00     33   1462
# 2023-07-07 17:09:00     44   1462
# ...                    ...    ...
# 2023-07-27 07:46:00     49   1462
# 2023-07-27 08:37:00      5   1462
# 2023-07-27 16:43:00     87   1462
# 2023-07-27 17:34:00      2   1462
# 2023-08-01 18:32:00      1   1462
#
# [124 rows x 2 columns]

# %%
def raw_pixel_times(fireID, date_string, year = "2023", path_region = "QuebecGlobalNRT_3571"):
    '''
    Function that finds raw times assosiated with VIIRS observations given a datetime and a fireID. 
    Will open up serialization file pickle object to find data. 
    Recommended to make the date-string as late in fire timeseries as possbile. 
        
    INPUTS:
        
        fireID (int): fireID of fire of interest.
        date_string (str): Date of serialization file to read in. Format of %Y%m%d%p  ex: '20230801AM'.
        year (str): Year that fires took place. Default to 2023. Availible options differ by path_region. 
        path_region (str): This constructs the path that the fires are stored in. Default to QuebecGlobalNRT_3571/ 
        
    '''
    import pickle
    import pandas as pd
    sys.path.insert(0, '/projects/fireatlas_nrt/')
    path = "/projects/shared-buckets/gsfc_landslides/FEDSoutput-s3-conus/"+ path_region + "/"+ year + "/Serialization/" + "20230801PM" + ".pkl"

    # open a file, where you stored the pickled data
    file = open(path, 'rb')

    # dump information to that file
    data = pickle.load(file)

    # close the file
    file.close()
    
    fireID = int(fireID)
    
    times = []
    for i in range(0, len(data.fires[fireID].pixels)):
        #print(i)
        times.append(data.fires[fireID].pixels[i].datetime)
    
    times = pd.DataFrame(times, columns = ['t'])
    times = times.sort_values(by = ['t'])
    times["count"] = 1
    times_grp = times.groupby("t").count()
    times_grp["fireID"] = str(fireID)
    
    return(times_grp)

# %%
test = raw_pixel_times(1462, "20230801PM")
test
# Out:
#                      count fireID
# t
# 2023-07-07 06:29:00     13   1462
# 2023-07-07 07:20:00     22   1462
# 2023-07-07 08:09:00      2   1462
# 2023-07-07 16:20:00     33   1462
# 2023-07-07 17:09:00     44   1462
# ...                    ...    ...
# 2023-07-27 07:46:00     49   1462
# 2023-07-27 08:37:00      5   1462
# 2023-07-27 16:43:00     87   1462
# 2023-07-27 17:34:00      2   1462
# 2023-08-01 18:32:00      1   1462
#
# [124 rows x 2 columns]

# %% [raw]
# 2023-07-07 07:20:00
# 2023-07-07 07:20:00
# 2023-07-07 08:09:00
# 2023-07-07 17:09:00
# 2023-07-07 17:09:00
# 2023-07-07 17:09:00
# 2023-07-07 17:09:00
# 2023-07-07 17:09:00
# 2023-07-07 17:09:00
# 2023-07-07 18:49:00
# 2023-07-07 18:49:00
# 2023-07-07 18:49:00
# 2023-07-07 18:49:00
# 2023-07-07 18:49:00
# 2023-07-07 16:20:00
# 2023-07-07 16:20:00
# 2023-07-07 16:20:00
# 2023-07-07 16:20:00
# 2023-07-07 18:00:00
# 2023-07-07 18:00:00
# 2023-07-07 18:00:00
# 2023-07-07 18:00:00
# 2023-07-07 18:00:00
# 2023-07-08 07:01:00
# 2023-07-08 07:52:00
# 2023-07-08 07:52:00
# 2023-07-08 07:52:00
# 2023-07-08 07:52:00
# 2023-07-09 06:42:00
# 2023-07-09 07:33:00

# %%
data.heritages

tmp = dict(data.heritages)
tmp2 = dict((v, k) for k, v in tmp.items())

# %%
tmp2[1462]
# Out:
# 1694

# %%
old_ids = [item for item in data.heritages if 1462 in item]

old_ids = [item[0] for item in old_ids]

old_ids.append(1462)

# %%
# times = []
# for f in old_ids:
#     t = data.fires[f].pixels[0].datetime
#     times.append(t)
# print(times)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 times.unique()
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
old_ids
# Out:
# [1773,
#  1762,
#  1645,
#  1763,
#  1541,
#  1831,
#  1569,
#  1754,
#  1648,
#  1542,
#  1531,
#  1599,
#  1561,
#  1697,
#  1534,
#  1765,
#  1776,
#  1659,
#  1738,
#  1716,
#  1795,
#  1533,
#  1757,
#  1746,
#  1574,
#  1602,
#  1468,
#  1670,
#  1564,
#  1643,
#  1632,
#  1526,
#  1605,
#  1567,
#  1692,
#  1749,
#  1760,
#  1817,
#  1722,
#  1471,
#  1779,
#  1752,
#  1741,
#  1780,
#  1558,
#  1714,
#  1597,
#  1463,
#  1771,
#  1654,
#  1810,
#  1559,
#  1578,
#  1646,
#  1540,
#  1782,
#  1755,
#  1744,
#  1570,
#  1812,
#  1785,
#  1774,
#  1668,
#  1747,
#  1736,
#  1687,
#  1766,
#  1649,
#  1660,
#  1543,
#  1717,
#  1600,
#  1562,
#  1535,
#  1777,
#  1603,
#  1739,
#  1565,
#  1796,
#  1818,
#  1807,
#  1690,
#  1758,
#  1769,
#  1720,
#  1469,
#  1480,
#  1693,
#  1671,
#  1750,
#  1655,
#  1644,
#  1538,
#  1712,
#  1595,
#  1606,
#  1830,
#  1568,
#  1557,
#  1772,
#  1761,
#  1598,
#  1560,
#  1802,
#  1742,
#  1753,
#  1764,
#  1647,
#  1821,
#  1783,
#  1532,
#  1688,
#  1666,
#  1822,
#  1571,
#  1745,
#  1784,
#  1601,
#  1658,
#  1669,
#  1563,
#  1631,
#  1756,
#  1593,
#  1718,
#  1467,
#  1650,
#  1786,
#  1775,
#  1748,
#  1759,
#  1737,
#  1642,
#  1816,
#  1778,
#  1767,
#  1527,
#  1661,
#  1740,
#  1768,
#  1691,
#  1596,
#  1653,
#  1809,
#  1536,
#  1721,
#  1470,
#  1604,
#  1751,
#  1577,
#  1808,
#  1713,
#  1539,
#  1781,
#  1770,
#  1743,
#  1811,
#  1694,
#  1462]
