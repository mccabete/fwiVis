# %%
! pip install ../utility_functions/
# Out:
# Processing /home/jovyan/fwiVis/utility_functions
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: s3fs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2024.6.1)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (1.26.4)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2.2.2)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (1.0.1)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (3.9.2)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2024.7.0)
# Requirement already satisfied: rioxarray in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.17.0)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (1.3.10)
# Requirement already satisfied: geocube in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.6.0)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2.0.5)
# Requirement already satisfied: folium in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (3.1.4)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (2.32.3)
# Requirement already satisfied: xyzservices in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (2024.6.0)
# Requirement already satisfied: appdirs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (1.4.4)
# Requirement already satisfied: click>=6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (8.1.7)
# Requirement already satisfied: odc-geo in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (0.4.8)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (1.14.0)
# Requirement already satisfied: pyproj>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (3.6.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geopandas->fwiVis==0.1) (0.9.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geopandas->fwiVis==0.1) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2024.1)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (2.4.0)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (24.2.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (2024.8.30)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (1.4.7)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (1.1.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (72.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (1.4.5)
# Requirement already satisfied: pillow>=8 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (3.1.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (2.13.2)
# Requirement already satisfied: fsspec==2024.6.1.* in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (2024.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (3.10.4)
# Requirement already satisfied: botocore<1.34.132,>=1.34.70 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.34.131)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (0.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (2.3.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jinja2>=2.9->folium->fwiVis==0.1) (2.1.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->fwiVis==0.1) (1.16.0)
# Requirement already satisfied: cachetools in /srv/conda/envs/notebook/lib/python3.12/site-packages (from odc-geo->geocube->fwiVis==0.1) (5.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (1.26.19)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from botocore<1.34.132,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.0.1)
# Building wheels for collected packages: fwiVis
#   Building wheel for fwiVis (setup.py) ... done
#   Created wheel for fwiVis: filename=fwiVis-0.1-py3-none-any.whl size=17875 sha256=75a71aef4dabd39e9fb3c08f2ef0a182ac412f0cb345e39e2ed0f4c1c154d1de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yipa_fhg/wheels/79/0f/3d/08c18473dd7e0fb915900e6b4f13b81f1fa84371f9bf24d864
# Successfully built fwiVis
# Installing collected packages: fwiVis
# Successfully installed fwiVis-0.1

# %%
import fwiVis.fwiVis as fv
import s3fs
s3 = s3fs.S3FileSystem(anon=False)
from math import cos, asin, sqrt
import re

import numpy as np
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
import os
import rioxarray as rio
import xarray as xr
import rasterio
import glob
from shapely.errors import ShapelyDeprecationWarning
from shapely.geometry import Point
import warnings
import folium
import datetime
import time
from folium import plugins
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
#import contextily as cx
from shapely.geometry import box
import sys
from datetime import datetime, timedelta
from itertools import chain
from bs4 import BeautifulSoup # I mamba installed bs4
import requests

from datetime import date
