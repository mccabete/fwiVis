# %%
# !pip install ~/fwiVis/utility_functions/
# Out:
# Processing /home/jovyan/fwiVis/utility_functions
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: s3fs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2025.7.0)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2.2.6)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2.3.1)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (1.1.1)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (3.10.5)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2025.7.1)
# Requirement already satisfied: rioxarray in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.19.0)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (1.4.3)
# Requirement already satisfied: geocube in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.7.1)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (2.1.1)
# Requirement already satisfied: folium in /srv/conda/envs/notebook/lib/python3.12/site-packages (from fwiVis==0.1) (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (3.1.6)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (2.32.4)
# Requirement already satisfied: xyzservices in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium->fwiVis==0.1) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jinja2>=2.9->folium->fwiVis==0.1) (3.0.2)
# Requirement already satisfied: appdirs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (1.4.4)
# Requirement already satisfied: click>=6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (8.2.1)
# Requirement already satisfied: odc_geo in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (0.5.0rc1)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (1.16.1)
# Requirement already satisfied: pyproj>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocube->fwiVis==0.1) (3.7.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geopandas->fwiVis==0.1) (0.11.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geopandas->fwiVis==0.1) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->fwiVis==0.1) (2025.2)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas->fwiVis==0.1) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->fwiVis==0.1) (1.17.0)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (2.4.0)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (25.3.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (0.7.2)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (1.1.1.2)
# Requirement already satisfied: pyparsing in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rasterio->fwiVis==0.1) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->fwiVis==0.1) (11.3.0)
# Requirement already satisfied: cachetools in /srv/conda/envs/notebook/lib/python3.12/site-packages (from odc_geo->geocube->fwiVis==0.1) (5.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->folium->fwiVis==0.1) (1.26.19)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (2.24.0)
# Requirement already satisfied: fsspec==2025.7.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (2025.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from s3fs->fwiVis==0.1) (3.12.15)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (0.12.0)
# Requirement already satisfied: botocore<1.39.12,>=1.39.9 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.39.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (6.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fwiVis==0.1) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (1.20.1)
# Requirement already satisfied: typing-extensions>=4.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->fwiVis==0.1) (4.14.1)
# Building wheels for collected packages: fwiVis
#   DEPRECATION: Building 'fwiVis' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fwiVis'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for fwiVis (setup.py) ... done
#   Created wheel for fwiVis: filename=fwivis-0.1-py3-none-any.whl size=19718 sha256=86b1a3b1cc62df9f31e9f759a076275e62c631bc4223d89c99fabff2925575cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d9arf6to/wheels/79/0f/3d/08c18473dd7e0fb915900e6b4f13b81f1fa84371f9bf24d864
# Successfully built fwiVis
# Installing collected packages: fwiVis
# Successfully installed fwiVis-0.1

# %%
import fwiVis.fwiVis as fv
import s3fs
s3 = s3fs.S3FileSystem(anon=False)
from math import cos, asin, sqrt
import re

import numpy as np
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
import os
import rioxarray as rio
import xarray as xr
import rasterio
import glob
from shapely.errors import ShapelyDeprecationWarning
from shapely.geometry import Point
import warnings
import folium
import datetime
import time
from folium import plugins
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 
import contextily as cx
from shapely.geometry import box
import sys
from datetime import datetime, timedelta
from itertools import chain

from datetime import date

import seaborn as sns

# sys.path.insert(0, '/projects/old_shared/fire_weather_vis/base-fwi-vis/')
# import fwiVis.fwiVis as fv

# %% [markdown]
# # Notes on calculations
#
# Calulation and definitions found here:
#
# https://www.css.cornell.edu/faculty/dgr2/_static/files/R_html/ModelEvaluation.html#1_Introduction
#
# ## Although they say observed - predicted which is clearly wrong

# %%
#path = "/projects/old_shared/fire_weather_vis/Lightning_analysis/fwi_timeline_merge/Final_dataset_as_of_20240209.csv"
# path = f"{os.path.abspath('data')}/Quebec_v3_full_data_perimeters20241112.csv"

# small_fire = fv.prep_fire_files(path)
# small_fire = small_fire[~small_fire.geometry.isna()]

# fire = fv.prep_fire_files(path)
# fire = fire[~fire.geometry.isna()]

small_fire = fv.formatting_read_in('data/Quebec_v3_full_data_perimeters20241112.csv', start_time = '2023-05-31 00:00:00', end_time = '2023-09-15 12:00:00', gen_cols = False, merge_with_ciffc = False, merge_with_nbac = True)
fire = small_fire = fv.formatting_read_in('data/Quebec_v3_full_data_perimeters20241112.csv', start_time = '2023-05-31 00:00:00', end_time = '2023-09-15 12:00:00', gen_cols = False, merge_with_ciffc = False, merge_with_nbac = True)
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/fwiVis/fwiVis.py:1335: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   fire3 = fire3.groupby("fireID").apply(chop_fires_at_end).reset_index(drop = True)
# Skipping field prov_code: unsupported OGR type: 5
# Skipping field prov_name_en: unsupported OGR type: 5
# WARNING: Intersecting with CIFFC will subset fires, but will make the generation of some column variables different after the fact. It is recommended to generate variable columns BEFORE CIFFC spatial joins
# /srv/conda/envs/notebook/lib/python3.12/site-packages/fwiVis/fwiVis.py:1335: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   fire3 = fire3.groupby("fireID").apply(chop_fires_at_end).reset_index(drop = True)
# Skipping field prov_code: unsupported OGR type: 5
# Skipping field prov_name_en: unsupported OGR type: 5
# WARNING: Intersecting with CIFFC will subset fires, but will make the generation of some column variables different after the fact. It is recommended to generate variable columns BEFORE CIFFC spatial joins

# %%
#fire[fire.fireID == '9791'].t.max() ## Yes, has FWI from when fires is not burning. 

#fire = fire[~fire.geometry.isna()] ## Subset to just when fires are burning (Should do? What about lead up to?)

# %%
### Ok, see if you can get rid of duplicates for the purposes of plotting 

small_fire = small_fire[['GEOS-5.IMERGEARLY',
       'FWI', 'FWI_lead_1', 'FWI_lead_2', 'FWI_lead_3', 'FWI_lead_4',
       'FWI_lead_5', 'FWI_lead_6', 'FWI_lead_7', 'FWI_lead_8' ]] # 'pre_fire'
small_fire = small_fire.drop_duplicates()




#small_fire.columns

# %%
##### Functions for per-FWI value sampling

def get_mid(interval):
    return interval.right

## Calculate the varience at different FWI and lag values
#small_fire["FWI_round"] = np.round(small_fire.FWI)
#small_fire["FWI_round"][small_fire["FWI_round"] >= 17] = 17
# nbins = 10
# small_fire["FWI_intervals"] = pd.qcut(small_fire.FWI.dropna(), nbins)
# small_fire["FWI_round"] = small_fire.FWI_intervals.apply(lambda x: get_mid(x))



def calc_bias(df, i):
    tmp = np.sum( df[f"FWI_lead_{i}"] - df["FWI"])/len(df[f"FWI_lead_{i}"])
    #print(len(df["FWI"]))
    return(tmp)


def RMSE(df, i):
    tmp = (np.sum((df[f"FWI_lead_{i}"] - df["FWI"])**(2))/len(df[f"FWI_lead_{i}"]))**(1/2)
    return(tmp)


def FWI_bootstrap_stat_quantiles(df,i,  num_samps, stat, resample_n = 50, quantiles = [0.025, 0.975]):
    '''
    like function above, but passes df so that it works with group_by better
    '''
    stat_list = []
    
    if(resample_n is None):
        resample_n = len(df)
        
    for n in range(1, num_samps):
        
        resample = df[["FWI", f"FWI_lead_{i}"]].dropna().sample(n = (resample_n), replace = True)
        # print(len(resample.iloc[:, 0].unique()))
        # print(len(resample.iloc[:, 0].dropna().unique()))
        #get_stat = stat(resample.iloc[:, 0], resample.iloc[:, 1])
        get_stat = stat(resample, i)
        # print(get_stat)
        # print(1 - (np.sum((resample.iloc[:, 0] - resample.iloc[:, 1])**(2)) / np.sum((resample.iloc[:, 0] - resample.iloc[:, 1].mean())**(2))))
        stat_list.append(get_stat)
    #print(stat_list)
    
    #print(np.quantile(stat_list, q = quantiles))
    list_of_tuples = list(zip(np.quantile(stat_list, q = quantiles), quantiles))
    quant_df = pd.DataFrame(list_of_tuples, columns=[f'{stat.__name__}_of_{resample.columns[0]}_and_{resample.columns[1]}', 'quantiles'])
    return(quant_df)

# %%
def fr_sq(s, s_pred):
    n = 1 - (np.sum((s - s_pred)**(2)) / np.sum((s - s_pred.mean())**(2)))
    return(n)
    
def fbias(s, s_pred):
    n = np.sum( (s_pred - s) )/len(s_pred)
    return(n)

def frmse(s, s_pred):
    n = ((np.sum((s_pred - s)**2))/len(s_pred))**(1/2)
    return(n)
    

def bootstrap_stat_quantiles(df, num_samps, stat, quantiles = [0.025, 0.975], resample_n = None):
    '''
    df (dataframe) a dataframe where the first column is s and second is s_pred
    '''
    stat_list = []
    
    if(resample_n is None):
        resample_n = len(df)
    
    for n in range(1, num_samps):
        
        resample = df.dropna().sample(n = (resample_n), replace = True)
        # print(len(resample.iloc[:, 0].unique()))
        # print(len(resample.iloc[:, 0].dropna().unique()))
        get_stat = stat(resample.iloc[:, 0], resample.iloc[:, 1])
        # print(get_stat)
        # print(1 - (np.sum((resample.iloc[:, 0] - resample.iloc[:, 1])**(2)) / np.sum((resample.iloc[:, 0] - resample.iloc[:, 1].mean())**(2))))
        stat_list.append(get_stat)
    #print(stat_list)
    
    #print(np.quantile(stat_list, q = quantiles))
    list_of_tuples = list(zip(np.quantile(stat_list, q = quantiles), quantiles))
    quant_df = pd.DataFrame(list_of_tuples, columns=[f'{stat.__name__}_of_{resample.columns[0]}_and_{resample.columns[1]}', 'quantiles'])
    return(quant_df)

# %%
nbins = 10
small_fire["FWI_intervals"] = pd.qcut(small_fire.FWI.dropna(), nbins)
small_fire["FWI_round"] = small_fire.FWI_intervals.apply(lambda x: get_mid(x))

# %%
for i in range(1,9):
    small_fire[f"fwi_error_{i}"] =small_fire["FWI"] - small_fire[f"FWI_lead_{i}"]

# %%
for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    plt.scatter(small_fire.FWI, small_fire[f"fwi_error_{i}"])
    plt.xlabel("FWI")
    plt.ylabel("Error")
    plt.title(f"Error at lag {i}")
    plt.show()

# %%
for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    plt.scatter(small_fire.FWI, small_fire[f"FWI_lead_{i}"])
    plt.xlabel("FWI")
    plt.ylabel(f"FWI_lead{i}")
    plt.title(f"Comparison at lag {i}")
    plt.show()

# %%
len(small_fire)
# Out:
# 2530

# %%
len(small_fire)
# Out:
# 2530

# %%
for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    plt.scatter(small_fire.FWI, small_fire[f"FWI_lead_{i}"])
    plt.xlabel("FWI")
    plt.ylabel(f"FWI_lead{i}")
    plt.title(f"Comparison at lag {i}")
    plt.show()

# %%
### BAD: BUT I JUST WANT TO LOOK TO SEE IF SUPER DIFFERENT

#small_fire["FWI"] = small_fire["GEOS-5.IMERGEARLY"]
#fire["FWI"] = fire["GEOS-5.IMERGEARLY"]

log_fire = small_fire
small_fire.columns
#log_fire = np.log(small_fire[['FWI', 'FWI_lead_1', 'FWI_lead_2', 'FWI_lead_3','FWI_lead_4', 'FWI_lead_5', 'FWI_lead_6', 'FWI_lead_7', 'FWI_lead_8']] + 1)
# Out:
# Index(['GEOS-5.IMERGEARLY', 'FWI', 'FWI_lead_1', 'FWI_lead_2', 'FWI_lead_3',
#        'FWI_lead_4', 'FWI_lead_5', 'FWI_lead_6', 'FWI_lead_7', 'FWI_lead_8',
#        'FWI_intervals', 'FWI_round', 'fwi_error_1', 'fwi_error_2',
#        'fwi_error_3', 'fwi_error_4', 'fwi_error_5', 'fwi_error_6',
#        'fwi_error_7', 'fwi_error_8'],
#       dtype='object')

# %%
# boot_df = small_fire.sample(n = len(small_fire)**2, replace = True, random_state = 4001, axis =0, ignore_index = True)

# print(len(boot_df))

# %%
np.quantile(small_fire[["FWI"]].dropna(), q = [0.025, 0.0975])
# Out:
# array([0.00402661, 0.12575953])

# %%
  
    
test_rsq = bootstrap_stat_quantiles(small_fire[["FWI", "FWI_lead_1"]].dropna(), num_samps = 300, stat = fr_sq, quantiles = [0.025, 0.975])

# %%
#bootstrap_stat_quantiles(log_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = 300, stat = r_sq, quantiles = quantiles)

#r_sq(log_fire[["FWI"]].dropna(), log_fire[[f"FWI_lead_{i}"]].dropna())

# %%
r_sq_list = []
bias_list = []
rmse_list = []
iterator = []

ctime = datetime.now()
date = ctime.strftime("%Y-%m-%d")

quantiles = [0.025, 0.975]
data = {'quantiles': quantiles}

boot_rmse = pd.DataFrame(data)
boot_r_sq = pd.DataFrame(data)
boot_bias = pd.DataFrame(data)

boot_samps = 100000

for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    sns.jointplot(data=log_fire, x="FWI", y=f"FWI_lead_{i}", marker="+") 
    plt.plot(range(0,28), range(0,28), color = "black")
    plt.xlabel("FWI")
    plt.ylabel(f"FWI_lead{i}")
    
    ## Stats
    r_sq = 1 - (np.sum((log_fire.FWI - log_fire[f"FWI_lead_{i}"])**(2)) / np.sum((log_fire.FWI - log_fire.FWI.mean())**(2)))
    bias = np.sum( log_fire[f"FWI_lead_{i}"] - log_fire.FWI )/len(log_fire[f"FWI_lead_{i}"])
    rmse = ((np.sum((log_fire[f"FWI_lead_{i}"] - log_fire.FWI)**2))/len(log_fire[f"FWI_lead_{i}"]))**(1/2)
    #print(log_fire[["FWI", f"FWI_lead_{i}"]])
    b_rsq = bootstrap_stat_quantiles(log_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = boot_samps, stat = fr_sq, quantiles = quantiles)
    b_bias = bootstrap_stat_quantiles(log_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = boot_samps, stat = fbias, quantiles = quantiles)
    b_rmse = bootstrap_stat_quantiles(log_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = boot_samps, stat = frmse, quantiles = quantiles)
    ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
    ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
    #plt.title(f"Comparison at lag {i}")
    print(f"Summary Statistics for lag {i}")
    print("R^2 from 1:1 (Variance explained): " + str(r_sq) )
    print("Overall Bias/ mean predictor error: " + str(bias) )
    rmse_list.append(rmse)
    r_sq_list.append(r_sq)
    bias_list.append(bias)
    iterator.append(i)
    boot_rmse = boot_rmse.merge(b_rmse, on = "quantiles")
    boot_r_sq = boot_r_sq.merge(b_rsq, on = "quantiles")
    boot_bias = boot_bias.merge(b_bias, on = "quantiles")
    
    plt.savefig(f"{os.path.abspath('some_figs')}/correlation_plot_FWI_by_leadtime_{i}_from_{date}.png")  
    plt.show()
 

decay_stats = pd.DataFrame({"lag_day": iterator, "RMSE": rmse_list, "r_sq": r_sq_list, "bias":bias_list, })

# here "*" is used as a marker for scatterplot
# Out:
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 1
# R^2 from 1:1 (Variance explained): 0.9014094953129329
# Overall Bias/ mean predictor error: 0.17644293072129297
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 2
# R^2 from 1:1 (Variance explained): 0.7007411980224965
# Overall Bias/ mean predictor error: 0.2711147850234679
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 3
# R^2 from 1:1 (Variance explained): 0.49969752045838955
# Overall Bias/ mean predictor error: 0.23962534285457038
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 4
# R^2 from 1:1 (Variance explained): 0.4581447372706715
# Overall Bias/ mean predictor error: 0.24063989925900617
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 5
# R^2 from 1:1 (Variance explained): 0.2002377272513235
# Overall Bias/ mean predictor error: 0.05720933006518056
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# /tmp/ipykernel_166/1050018693.py:34: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
# Summary Statistics for lag 6
# R^2 from 1:1 (Variance explained): 0.008345979553305072
# Overall Bias/ mean predictor error: 0.08275258944322564
# /tmp/ipykernel_166/1050018693.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)

# %%
boot_rmse

# %%
stats = ["RMSE", "r_sq", "bias"]
b_sts = [ boot_rmse, boot_r_sq, boot_bias ]

for s,b in zip(stats, b_sts):
    plt.plot(decay_stats.lag_day, decay_stats[s], label = "All FWI Values")
    upper = b.iloc[0, 1:]
    lower = b.iloc[1, 1:]
    #print(b)
    plt.fill_between(decay_stats.lag_day, lower, upper, alpha=0.2, label='Confidence Interval')
    plt.xlabel("Forecast Lead Time")
    plt.ylabel(s)
    plt.savefig(f"{os.path.abspath('some_figs')}/all_FWI_{s}_plot_{boot_samps}_samples_from_{date}.png")
    plt.show()

# %%
bins = 10
slices = np.linspace(0, 100, bins+1, True)
slices

# %%
tmp = pd.qcut(small_fire.FWI.dropna(), 20, precision = 0)

tmp

# %%
#small_fire.FWI_round.unique()

# %%
#cmap = plt.get_cmap('viridis')

nbins = 10
small_fire["FWI_intervals"] = pd.qcut(small_fire.FWI.dropna(), nbins)
small_fire["FWI_round"] = small_fire.FWI_intervals.apply(lambda x: get_mid(x))

colors = plt.cm.viridis(np.linspace(0,1,9))

for i in range(1,9):
    test_var = small_fire.groupby("FWI_round")[f"FWI_lead_{i}"].var().reset_index()
    #plt.plot(test_var.FWI_round, test_var[f"FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.plot(test_var.FWI_round, test_var[f"FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.xlabel("FWI")
    plt.ylabel(f"Variance")
    plt.legend()
    #plt.title(f"Comparison at lag {i}")

#plt.savefig(f"/projects/old_shared/fire_weather_vis/Lightning_analysis/some_figs/var_by_FWI_{nbins}_bins_from_{date}.png")
plt.savefig(f"{os.path.abspath('some_figs')}/var_by_FWI_{nbins}_bins_from_{date}.png")
plt.show()

# %%
#boot_df

# %%
max(quantiles)

# %%
quantiles = [0.025, 0.975]
data = {'quantiles': quantiles}

#ci_df = pd.DataFrame(data)

for i in range(1,9):
    test_var = small_fire.groupby("FWI_round").apply(calc_bias, i = i).reset_index()
    #print(test_var)
    ci = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
    #print(ci)
    #ci_df = ci_df.merge(ci, on = "quantiles")
    upper = ci[ci.quantiles == max(quantiles)].iloc[:, 0]
    lower = ci[ci.quantiles == min(quantiles)].iloc[:, 0]
    #print(b)
    plt.fill_between(test_var.FWI_round, lower.astype("float64"), upper.astype("float64"), alpha=0.2, label='', color = colors[i])
    test_var = test_var.rename(columns={0:f"FWI_lead_{i}"})
    plt.plot(test_var.FWI_round, test_var[f"FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.xlabel("FWI")
    plt.ylabel(f"Bias")
    plt.legend()
    #plt.title(f"Comparison at lag {i}")
plt.savefig(f"{os.path.abspath('some_figs')}/calc_bias_by_FWI_{nbins}_{boot_samps}_samples_bins_from_{date}.png")
plt.show()

# %%
for i in range(1,9):
    test_var = small_fire.groupby("FWI_round").apply(RMSE, i = i).reset_index()
    #print(test_var)
    test_var = test_var.rename(columns={0:f"FWI_lead_{i}"})
    ci = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = 300, stat = RMSE, quantiles = quantiles)
    #print(ci)
    #ci_df = ci_df.merge(ci, on = "quantiles")
    upper = ci[ci.quantiles == max(quantiles)].iloc[:, 0]
    lower = ci[ci.quantiles == min(quantiles)].iloc[:, 0]
    #print(b)
    plt.fill_between(test_var.FWI_round, lower.astype("float64"), upper.astype("float64"), alpha=0.2, label='', color = colors[i])
    #print(test_var)
    plt.plot(test_var.FWI_round, test_var[f"FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.xlabel("FWI")
    plt.ylabel(f"RMSE")
    #lt.legend()
    #plt.title(f"Comparison at lag {i}")
plt.savefig(f"{os.path.abspath('some_figs')}/RMSE_by_FWI_{nbins}_{boot_samps}_samples_bins_from_{date}.png")
plt.show()


#asjbgalibadlkba

# %% [markdown]
# # Now try to see if I can capture "changes in the timeseries".
#
# The goal is to find a mechnism that rewards capturing inflection points. This could have a couple of meanings:
#
# "How many days in advance did we get the inflection point correct" <-- possbily useful interpretation
#
#
# "Were we able to spot the inflection point when the
#
#
# "Were we better at predicting the weather when it was getting hotter(more FWI) ore colder (less FWI)?"
# - Calculate deltas, color-code scatterplots by deltas? Calculate r^2 on binned-deltas like I'm doing with Bias/ variance?
# - plot delta vs delta like above
# - somehow plot delta skill one axis, FWI on other
#     - T_4 - T_3, indexed by T_4  compared to forecasted T_4 - T_3 @ T_4 (actual) (Aka "The difference between
#         - FWI @T_3 = 10 FWI @T_4 = 16, forecastsed @T_3 was 6 and @ T_4 was 9. "Real delta" was 6, "Forecasted delta" was 3. @ FWI of 16, Delta forecast was off by 3

# %%
small_fire

# %%
fire_delta = fire.sort_values(by = ["fireID", "t"])

# %%
def group_level_diff(df, var):
    df["diff_" + var] = df[var].diff()
    return(df)

# %%
fire_delta = fire_delta[["fireID", "t", 'GEOS-5.IMERGEARLY',
       'FWI', 'FWI_lead_1', 'FWI_lead_2', 'FWI_lead_3', 'FWI_lead_4',
       'FWI_lead_5', 'FWI_lead_6', 'FWI_lead_7', 'FWI_lead_8']]

#fire_delta = fire_delta.groupby("fireID").apply(group_level_diff, "FWI").reset_index()

# %%
# smol = fire_delta[fire_delta.fireID == "10013"]

# smol["diff_FWI"] = smol.FWI.diff()
# #smol[~smol.FWI.isna()]
# smol[smol.t >= "2023-05-03"]

# %%
fire_delta = fire_delta[fire_delta.t.astype("str").str.contains("12:00:00")]

fire_delta = fire_delta.groupby("fireID").apply(group_level_diff, "FWI").reset_index( drop = True)


for i in range(1,9):
    fire_delta = fire_delta.groupby("fireID").apply(group_level_diff, f"FWI_lead_{i}").reset_index( drop = True)
fire_delta

# %%
fire_delta.columns

# %%
### Drop duplicates to account for oversampling

fire_delta = fire_delta[['FWI', 'FWI_lead_1', 'FWI_lead_2', 'FWI_lead_3', 'FWI_lead_4',
       'FWI_lead_5', 'FWI_lead_6', 'FWI_lead_7', 'FWI_lead_8', 'diff_FWI', 'diff_FWI_lead_1', 'diff_FWI_lead_2',
       'diff_FWI_lead_3', 'diff_FWI_lead_4', 'diff_FWI_lead_5',
       'diff_FWI_lead_6', 'diff_FWI_lead_7', 'diff_FWI_lead_8']]
fire_delta = fire_delta.drop_duplicates()


### Summary stats for CHANGE in FWI predictions

for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    sns.jointplot(data=fire_delta, x="diff_FWI", y=f"diff_FWI_lead_{i}", marker="+") 
    max_of_max = round(max(fire_delta[f"diff_FWI_lead_{i}"].max(), fire_delta.diff_FWI.max()))
    min_of_min = round(min(fire_delta[f"diff_FWI_lead_{i}"].min(), fire_delta.diff_FWI.min()))
    
    
    plt.plot(range(min_of_min, max_of_max), range(min_of_min, max_of_max), color = "black")
    plt.xlabel("diff_FWI")
    plt.ylabel(f"diff_FWI_lead_{i}")
    
    ## Stats
    r_sq = 1 - (np.sum((fire_delta.diff_FWI - fire_delta[f"diff_FWI_lead_{i}"])**(2)) / np.sum((fire_delta.diff_FWI - fire_delta.diff_FWI.mean())**(2)))
    bias = np.sum(fire_delta[f"diff_FWI_lead_{i}"] - fire_delta.diff_FWI )/len(fire_delta.diff_FWI)
    #plt.title(f"Comparison at lag {i}")
    print(f"Summary Statistics for lag {i}")
    print("R^2 from 1:1 (Variance explained): " + str(r_sq) )
    print("Overall Bias/ mean predictor error: " + str(bias) )
    plt.show()

# %%
fire_delta

# %%
#type(fire_delta.FWI)

#tmp = pd.cut(fire_delta.FWI.values, bins= 5, include_lowest = True)

# %%
### See if there is systematic bias in the differenced stuff

## Calculate the varience at different FWI and lag values
fire_delta["FWI_round"] = np.round(fire_delta.FWI)
fire_delta["FWI_round"][fire_delta["FWI_round"] > 17] = 17
#fire_delta["FWI_binned"] = pd.cut(fire_delta.FWI.values, bins= 5, include_lowest = True) ## Becomes catagorical data an messes up plotting below


# def calc_bias(df, i):
#     tmp = np.sum(df[f"FWI_lead_{i}"] - df["FWI"])/len(df[f"FWI_lead_{i}"])
#     return(tmp)

def calc_bias_diff(df, i):
    tmp = np.sum( df[f"diff_FWI_lead_{i}"] - df["diff_FWI"])/len(df[f"diff_FWI_lead_{i}"])
    #print(len(df[f"diff_FWI_lead_{i}"]))
    #print(df["FWI_round"].unique())
    return(tmp)

def RMSE_diff(df, i):
    tmp = (np.sum((df[f"diff_FWI_lead_{i}"] - df["diff_FWI"])**(2))/len(df[f"diff_FWI_lead_{i}"]))**(1/2)
    return(tmp)

    

#cmap = plt.get_cmap('viridis')
colors = plt.cm.viridis(np.linspace(0,1,9))

bin_var = "FWI_round" # "FWI_round"
for i in range(1,9):
    test_var = fire_delta.groupby(bin_var).apply(calc_bias_diff, i = i).reset_index()
    #print(test_var)
    test_var = test_var.rename(columns={0:f"diff_FWI_lead_{i}"})
    plt.plot(test_var[bin_var], test_var[f"diff_FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.xlabel("FWI")
    plt.ylabel(f"Bias ")
    plt.title("Bias in difference errors")
    plt.legend()
    #plt.title(f"Comparison at lag {i}")
plt.show()

# %%
bin_var = "FWI_round" # "FWI_round"
for i in range(1,9):
    test_var = fire_delta.groupby(bin_var).apply( RMSE_diff, i = i).reset_index()
    #print(test_var)
    test_var = test_var.rename(columns={0:f"diff_FWI_lead_{i}"})
    plt.plot(test_var[bin_var], test_var[f"diff_FWI_lead_{i}"], label = f"Lead {i}", color = colors[i])
    plt.xlabel("FWI")
    plt.ylabel(f"RMSE ")
    plt.title("RMSE in difference errors")
    plt.legend()
    #plt.title(f"Comparison at lag {i}")
plt.show()

# %%
## Plot error by FWI

for i in range(1,9):
    # plt.scatter(small_fire.FWI, (small_fire[f"fwi_error_{i}"] * small_fire[f"fwi_error_{i}"])**(1/2))
    sns.jointplot(data=fire_delta, y="FWI", x=fire_delta.diff_FWI - fire_delta[f"diff_FWI_lead_{i}"], marker="+") 
    #max_of_max = round(max(fire_delta[f"diff_FWI_lead_{i}"].max(), fire_delta.diff_FWI.max()))
    #min_of_min = round(min(fire_delta[f"diff_FWI_lead_{i}"].min(), fire_delta.diff_FWI.min()))
    
    
    #plt.plot(range(min_of_min, max_of_max), range(min_of_min, max_of_max), color = "black")
    plt.ylabel("FWI")
    plt.xlabel(f" Error in differece from lead_{i}")
    
    ## Stats
    plt.show()

# %% [markdown]
# ### Trying to recreate the error statistics by forecast lead time with FWI as the color bar instead of the other way around

# %%
#nbins = 5
# small_fire["FWI_intervals"] = pd.qcut(small_fire.FWI.dropna(), nbins)
# small_fire["FWI_round"] = small_fire.FWI_intervals.apply(lambda x: get_mid(x))


interval_defs = [small_fire.FWI.min(), 2, 7.3, small_fire.FWI.max()]
interval_labels = ["<2", "2-7.3", ">7.3"]

small_fire["FWI_intervals"] = pd.cut(small_fire.FWI, interval_defs, include_lowest = True, labels= None,  right=True)
small_fire["FWI_round"] = small_fire.FWI_intervals.apply(lambda x: get_mid(x))
small_fire["FWI_label"] = pd.cut(small_fire.FWI, interval_defs, include_lowest = True, labels= interval_labels,  right=True)
nbins = len(small_fire["FWI_intervals"].dropna().unique())

#foo = pd.cut(small_fire.FWI, [small_fire.FWI.min(), 2.5, 7, small_fire.FWI.max()], include_lowest = True, labels= ["<2.5", "2.5-7", ">7"],  right=True)
#foo

# %%
fwi_colors = plt.cm.copper(np.linspace(0,1,nbins))

# %%
# ci = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = 300, stat = calc_bias, quantiles = quantiles)

# %%
# boot_rmse

# %%
#small_fire["FWI_round"].hist()

# %%
# %%capture --no-stderr

r_sq_list = []
bias_list = []
rmse_list = []
iterator = []

quantiles = [0.025,0.5, 0.975]
data = {'quantiles': quantiles}


### Generate staring DFs with a multi-index 

# Use numpy to create a grid of these elements
level1_grid, level2_grid = np.meshgrid(quantiles, [*small_fire["FWI_round"].dropna().astype("float64")])

# Flatten the grids and create a list of tuples
index_tuples = list(zip(level1_grid.flatten(), level2_grid.flatten()))

# Create the MultiIndex
multi_index = pd.MultiIndex.from_tuples(index_tuples, names=[ 'quantiles', "FWI_round"])



boot_rmse = pd.DataFrame(data)
boot_r_sq = pd.DataFrame(data)
boot_bias = pd.DataFrame(data)

b_ci_bias = pd.DataFrame(index=multi_index) #pd.DataFrame({ "FWI_round" :[*small_fire["FWI_round"].dropna().astype("float64")]})
b_ci_RMSE = pd.DataFrame(index=multi_index) #pd.DataFrame({ "FWI_round" : [*small_fire["FWI_round"].dropna().astype("float64")]})

boot_samps = 100000


for i in range(1,9):

    
    ## Stats
    r_sq = 1 - (np.sum((small_fire.FWI - small_fire[f"FWI_lead_{i}"])**(2)) / np.sum((small_fire.FWI - small_fire.FWI.mean())**(2)))
    bias = np.sum( small_fire[f"FWI_lead_{i}"] - small_fire.FWI )/len(small_fire[f"FWI_lead_{i}"])
    rmse = ((np.sum((small_fire[f"FWI_lead_{i}"] - small_fire.FWI)**2))/len(small_fire[f"FWI_lead_{i}"]))**(1/2)
    #print(small_fire[["FWI", f"FWI_lead_{i}"]])
    b_rsq = bootstrap_stat_quantiles(small_fire[["FWI", f"FWI_lead_{i}"]].dropna(),  num_samps =  boot_samps, stat = fr_sq, quantiles = quantiles)
    b_bias = bootstrap_stat_quantiles(small_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = boot_samps, stat = fbias, quantiles = quantiles)
    b_rmse = bootstrap_stat_quantiles(small_fire[["FWI", f"FWI_lead_{i}"]].dropna(), num_samps = boot_samps, stat = frmse, quantiles = quantiles)
    ci_bias = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = calc_bias, quantiles = quantiles)
    ci_RMSE = small_fire.groupby("FWI_round").apply(FWI_bootstrap_stat_quantiles, i = i, num_samps = boot_samps, stat = RMSE, quantiles = quantiles)
    #plt.title(f"Comparison at lag {i}")
    # print(f"Summary Statistics for lag {i}")
    # print("R^2 from 1:1 (Variance explained): " + str(r_sq) )
    # print("Overall Bias/ mean predictor error: " + str(bias) )
    rmse_list.append(rmse)
    r_sq_list.append(r_sq)
    bias_list.append(bias)
    iterator.append(i)
    boot_rmse = boot_rmse.merge(b_rmse, on = "quantiles")
    boot_r_sq = boot_r_sq.merge(b_rsq, on = "quantiles")
    boot_bias = boot_bias.merge(b_bias, on = "quantiles")
    b_ci_bias = b_ci_bias.merge(ci_bias,  on = ['FWI_round', 'quantiles'])
    b_ci_bias =  b_ci_bias.drop_duplicates()
    b_ci_RMSE = b_ci_RMSE.merge(ci_RMSE,  on = ['FWI_round', 'quantiles'])### The merging here seems to be what is Memory intensive, along with the 'resample_n' parameter, to a lesser extent
    b_ci_RMSE = b_ci_RMSE.drop_duplicates()

decay_stats = pd.DataFrame({"lag_day": iterator, "RMSE": rmse_list, "r_sq": r_sq_list, "bias":bias_list, })

# %%
stats = ["RMSE", "bias"] #  "r_sq",
b_sts = [ boot_rmse,  boot_bias ] # boot_r_sq,
c_sts = [b_ci_RMSE, b_ci_bias]#[RMSE, calc_bias]
l_sts = range(0, len(small_fire["FWI_round"].dropna().unique()))
#int_sts = small_fire["FWI_intervals"].sort_values().dropna().unique()

ctime = datetime.now()
date = ctime.strftime("%Y-%m-%d")

for s,b,c in zip(stats, b_sts, c_sts):
    plt.plot(decay_stats.lag_day, decay_stats[s], label = "All FWI Values", color = "magenta", linestyle='dashed')
    upper = b.iloc[0, 1:]
    lower = b.iloc[1, 1:]
    #print(b)
    #plt.fill_between(decay_stats.lag_day, lower, upper, alpha=0.1, label='Confidence Interval', color="none", hatch="X")
    for n, l, in zip(small_fire["FWI_round"].sort_values().dropna().unique(), l_sts):
        print(n)
        #fwi_upper = c[(c.index == n) & (c.quantiles == min(quantiles))].iloc[:, 1:].transpose().values
        #fwi_lower = c[(c.index == n) & (c.quantiles == max(quantiles))].iloc[:, 1:].transpose().values
        # fwi_upper = c[(c.index == n) & (c.quantiles == min(quantiles))].iloc[:, 1:].values
        # fwi_lower = c[(c.index == n) & (c.quantiles == max(quantiles))].iloc[:, 1:].values
        fwi_upper = c[(c.index == n) & (c.quantiles == min(quantiles))].iloc[:, 1:].to_numpy().flatten()
        fwi_lower = c[(c.index == n) & (c.quantiles == max(quantiles))].iloc[:, 1:].to_numpy().flatten()
        fwi_mid = c[(c.index == n) & (c.quantiles == 0.5)].iloc[:, 1:].to_numpy().flatten()
        plt.plot(decay_stats.lag_day, fwi_mid, color = fwi_colors[l], label = str(*small_fire[small_fire.FWI_round == n].dropna().FWI_label.astype("str").unique()))
        #print(fwi_upper)
        #### Need to be sampling the mean I think to get a line
        plt.fill_between(decay_stats.lag_day, fwi_lower, fwi_upper, alpha=0.2, color = fwi_colors[l])
        


    plt.xlabel("Forecast Lead Time (Days)")
    plt.ylabel(s)
    # if(stats == "RMSE"):
    #     plt.legend()
    plt.legend()
    plt.savefig(f"{os.path.abspath("some_figs")}/stat_{s}_by_leadtime_{date}_{boot_samps}_bootsamps.png", dpi = 900, transparent = True)
    #plt.savefig(f"/projects/old_shared/fire_weather_vis/Lightning_analysis/some_figs/stat_{s}_by_leadtime_{date}_{boot_samps}_bootsamps.png")
    plt.show()

# %%
#path = "/projects/old_shared/fire_weather_vis/Lightning_analysis/fwi_timeline_merge/Quebec_all_fires_merged_together_06172024.csv" # Fires with "fixed' lf bug.
path = f"{os.path.abspath('data')}/Quebec_v3_full_data_perimeters20241112.csv"
fires = fv.prep_fire_files(path)

fires = fires.to_crs(4326)

# %%
fires = fires[fires.t.str.contains("12:00:00")] ## Need to get rid of the 00:00:00 values for correct farea difference values

fires["FWI_intervals"] = pd.cut(fires.FWI, interval_defs, include_lowest = True, labels= None,  right=True)
fires["FWI_round"] = fires.FWI_intervals.apply(lambda x: get_mid(x))
fires["FWI_label"] = pd.cut(fires.FWI, interval_defs, include_lowest = True, labels= interval_labels,  right=True)

# %%
fires = fires.sort_values(by = "t")
fires["farea_diff"] = fires.groupby("fireID").farea.diff()

fires.loc[(fires.farea_diff < 0), ["farea_diff"]] = 0 ### Because of merging, sometimes farea goes down.

# %%
import scipy.stats as sp


def custom_percentile_of_score(df, col = "farea_diff", kind = 'weak'):

    percent_score = sp.percentileofscore(df[col].dropna(), df[col], kind = kind)
    #print(percent_score)
    #print(np.sum(percent_score))
    df[f'{col}_percentile_of_score'] = percent_score
    return(df)
    #return(percent_score)

# %%
def chop_fires_at_end(df):
    if(len(df[df.n_newpixels > 0]) > 0 ): 
        final_t = df[df.n_newpixels > 0].t.max()
        df = df[df.t <= final_t]
    else:
        df = df[df.t == df.t.min()] ## If the fire had it's only growth increment during the 12 hour period we aren't looking at (ie spread in the AM overpass)
    return(df)

fires = fires.groupby("fireID").apply(chop_fires_at_end).reset_index(drop=True)

# %%
fires = fires.groupby("fireID").apply(custom_percentile_of_score, col = "farea_diff", kind='strict').reset_index(drop = True)

# %%
### Double check if percentiles "feel" right

fires.loc[(fires.fireID == '11221'), ['fireID', 't', 'n_pixels', 'n_newpixels', 'farea', 'fperim', 'duration', 'FWI_round', 'FWI_label', 'farea_diff',
       'farea_diff_percentile_of_score']].sort_values(by = "t")

# %%
### Print report on catagories
### Print out report on figure with useful numbers to report. 
print(f'Total number of  FWI fire day is {len(small_fire)}')
      
for i in small_fire["FWI_label"].unique():
      print(f'There were {len(small_fire[small_fire["FWI_label"] == i ])} entries in , {str(i)}')


        

ranks = list()
alt_ranks = []

grw = []
alt_grw = []

print(f"Amoung {len(fires.fireID.unique())} unique fires from {fires.t.min()} to {fires.t.max()}, there were {len(fires[fires.farea_diff_percentile_of_score >= 50])} total days where a fire grew > 50 rank percentile of it's growth. ")  
print(f" There were also {len(fires[(fires.farea_diff >= 5 )])} total days where a fire grew over 5 km^2")
for i in fires["FWI_label"].unique():
    num_rnk = len(fires[(fires.FWI_label == i) & (fires.farea_diff_percentile_of_score >= 50 )])
    a_rnk = len(fires[(fires.FWI_label == i) & (fires.farea_diff_percentile_of_score < 50 )])
    
    num_grw = len(fires[(fires.FWI_label == i) & (fires.farea_diff >= 5 )])
    a_grw = len(fires[(fires.FWI_label == i) & (fires.farea_diff < 5 )])
    print(f'{str(i)}, acounted for {num_rnk} of >= 50 rank percentile fire days.')
    print(f'{str(i)}, acounted for {num_grw} of days with >= 5km^2 of fire growth')

    ranks.append(num_rnk)
    alt_ranks.append(a_rnk)
    grw.append(num_grw)
    alt_grw.append(a_grw)

rats = pd.DataFrame({"Catagories":fires["FWI_label"].unique(), 
                    "50_perct_rank": ranks, 
                    "inv_50_perct_rank": alt_ranks, 
                    "5km_grew": grw, 
                    "inv_5km_grew": alt_grw})

# %%
## Calculate Odds Ratios for Catagories

cat_least_growth = rats[rats.inv_5km_grew == rats.inv_5km_grew.max()].Catagories.values
cat_least_growth = cat_least_growth[0]

for i in rats.Catagories.unique():
    odds_grew = (rats.loc[(rats.Catagories == i), ['5km_grew']].values / rats.loc[(rats.Catagories == i), ['inv_5km_grew']].values) / (rats.loc[(rats.Catagories == cat_least_growth), ['5km_grew']].values / rats.loc[(rats.Catagories == cat_least_growth), ['inv_5km_grew']].values)
    
    odds_50 = (rats.loc[(rats.Catagories == i), ['50_perct_rank']].values / rats.loc[(rats.Catagories == i), ['inv_50_perct_rank']].values) / (rats.loc[(rats.Catagories == cat_least_growth), ['50_perct_rank']].values / rats.loc[(rats.Catagories == cat_least_growth), ['inv_50_perct_rank']].values)
    
    print(f'{i} is {odds_grew} more likely to have a day with 5km^2 growth than {cat_least_growth}.')
    print(f'{i} is {odds_50} more likely to have a day with > 50th percentile level growth in a fire than {cat_least_growth}.')

# %%
rats

# %%
rats.loc[(rats.Catagories == i), ['5km_grew']].values / rats.loc[(rats.Catagories == i), ['inv_5km_grew']].values

# %%
(rats.loc[(rats.Catagories == cat_least_growth), ['5km_grew']].values) / rats.loc[(rats.Catagories == cat_least_growth), ['inv_5km_grew']].values

# %%
rats.loc[(rats.Catagories == cat_least_growth), ['5km_grew']].values

# %%
cat_least_growth[0]
